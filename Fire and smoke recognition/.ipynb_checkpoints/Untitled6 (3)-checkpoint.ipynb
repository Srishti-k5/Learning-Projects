# %%
import tensorflow as tf
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import PIL
import imgaug as ia
from imgaug.augmentables.bbs import BoundingBox
import glob
from moviepy.editor import *
import cv2
import math
from PIL import Image
import pandas as pd

# %%
#path the video
vidcap = cv2.VideoCapture(r"D:\Video_data\train\fire\fire1.mp4")
success, image = vidcap.read()
count = 0
while vidcap.isOpened():
    success, image = vidcap.read()
    if(success == False):
        break;
    cv2.imwrite(r"D:\Video_data\train\fire\images\%d.png" % count, image)
    count+=1

# %%
######################################################################################################################

i=0
Imagee = []
xCoord = []
yCoord = []
dat = []
dct = {}
effectiveArea = 0
area = []
hei = []
wid = []
Area =[]
for i in range(1):

    image_for_testing='D:/Video_data/train/fire/images'+"/"+str(i)+".png"
    
    
    img = cv2.imread(str(image_for_testing))

    # convert to grayscale
    hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    lower = np.array([0, 40, 200])
    upper = np.array([35, 215, 255])
    mask = cv2.inRange(hsv, lower, upper)
#         cv2.imshow("Edged image", mask)
#         cv2.waitKey(0)
    
#     blur= cv2.GaussianBlur(mask,(1,1),0)
    # threshold
#     element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7)) 
#     eroded=cv2.erode(blur,element)
#     thresh = cv2.threshold(eroded,170,255,cv2.THRESH_BINARY)[1]
#     cv2.imshow("Edged image", thresh)
#     cv2.waitKey(0)
#     cv2.imshow("Edged image", blur)
#     cv2.waitKey(0)
    # get contours
    result = img.copy()
    blur= cv2.GaussianBlur(mask,(7,7),0)
    contours = cv2.findContours(blur, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    contours = contours[0] if len(contours) == 2 else contours[1]
    for cntr in contours:
        x,y,w,h = cv2.boundingRect(cntr)
#         cv2.rectangle(result, (x, y), (x+w, y+h), (255, 255, 0), 2)
#         if(w*h > 500):
#             cv2.rectangle(result, (x, y), (x+w, y+h), (0, 0, 139), 2)
#             cv2.putText(result, "alert", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,0,255), 2)
#         if(w*h > 100 and w*h < 500):
#             cv2.rectangle(result, (x, y), (x+w, y+h), (139, 0, 0), 2)
# #             cv2.putText(result, (str(x)+","+str(y)), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1)
        if(w*h > 100 ):
            cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)
            
            
        xCoord = xCoord + [x]
        yCoord = yCoord + [y]
        hei = hei + [h]
        wid = wid + [w]
        
        area = area + [w*h]
        effectiveArea = effectiveArea + w*h 
    for cntr in contours:
        x,y,w,h = cv2.boundingRect(cntr)  
        hei = hei + [h]
        wid = wid + [w]
#         xCoord = xCoord + [x]
#         yCoord = yCoord + [y]
#         area = area + [w*h]
        for t in range(len(xCoord)):
#             if((hei[-1]*wid[-1])/effectiveArea >= 0 and (hei[-1]*wid[-1])/effectiveArea < 0.1):
# #             print(w*h/effectiveArea)
#                 cv2.rectangle(result, (x, y), (x+w, y+h), (255, 0, 0), 2)
#                 cv2.putText(result, "alert(5%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
            if((hei[-1]*wid[-1])/effectiveArea >= 0.5 and (hei[-1]*wid[-1])/effectiveArea < 0.1):
#              print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)
                cv2.putText(result, "alert(7%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
            if((hei[-1]*wid[-1])/effectiveArea >= 0.1 and (hei[-1]*wid[-1])/effectiveArea < 0.2):
#              print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)
                cv2.putText(result, "alert(15%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
            if((hei[-1]*wid[-1])/effectiveArea >= 0.2 and (hei[-1]*wid[-1])/effectiveArea < 0.3):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(25%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
            if((hei[-1]*wid[-1])/effectiveArea >= 0.3 and (hei[-1]*wid[-1])/effectiveArea < 0.4):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(35%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2) 
            if((hei[-1]*wid[-1])/effectiveArea >= 0.4 and (hei[-1]*wid[-1])/effectiveArea < 0.5):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(45%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2) 
            if((hei[-1]*wid[-1])/effectiveArea >= 0.5 and (hei[-1]*wid[-1])/effectiveArea < 0.6):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(55%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2) 
            if((hei[-1]*wid[-1])/effectiveArea >= 0.6 and (hei[-1]*wid[-1])/effectiveArea < 0.7):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(65%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2) 
            if((hei[-1]*wid[-1])/effectiveArea >= 0.7 and (hei[-1]*wid[-1])/effectiveArea < 0.8):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(75%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2) 
            if((hei[-1]*wid[-1])/effectiveArea >= 0.8 and (hei[-1]*wid[-1])/effectiveArea < 0.9):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(85%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2) 
            if((hei[-1]*wid[-1])/effectiveArea >= 0.9 and (hei[-1]*wid[-1])/effectiveArea < 1):
#             print(w*h/effectiveArea)
                cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 255), 2)
                cv2.putText(result, "alert(95%)", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2) 
##########################################################################
#for saving coordinates in the excel sheet
        

#############################################################################################################################

#########################################################################################
#     for l in range(len(xCoord)): # to left and left top and left buttom
#         for g in range(len(xCoord)-1):
#             if( g>l  and (yCoord[g]-(yCoord[l]+hei[l])<30 or yCoord[l]-(yCoord[g]+hei[g])<30) and xCoord[l]-(xCoord[g]+wid[g]) <30 and xCoord[l]-(xCoord[g]+wid[g]) >0):
#                     if(w*h > 100 ):
#                         cv2.rectangle(result, (xCoord[g], (yCoord[l])), ((xCoord[l]+wid[l]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
#             if( g>l and (yCoord[g]-(yCoord[l]+hei[l])<30 or yCoord[l]-(yCoord[g]+hei[g])<30) and ((xCoord[g]+wid[g])-(xCoord[l]) <30) and (xCoord[g]+wid[g])-(xCoord[l]) >0 ):
#                     if(w*h > 100 ):
#                         cv2.rectangle(result, (xCoord[g], yCoord[g]), ((xCoord[l]+wid[l]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
#             if( g>l and ((yCoord[l]-(yCoord[g]+hei[g])<30 and yCoord[l]-(yCoord[g]+hei[g])>0) or (yCoord[l]-(yCoord[g])<30 and yCoord[l]-(yCoord[g])>0)) and ((xCoord[g])-(xCoord[l]) > 0) and (xCoord[g]+wid[g])-(xCoord[l]+wid[l]) <0 ):
#                     if(w*h > 100):
#                         cv2.rectangle(result, (xCoord[g], yCoord[g]), ((xCoord[l]+wid[l]), (yCoord[g]+hei[g])), (0, 0, 0), 2)  
#             if( g>l and (yCoord[l]-(yCoord[g]+hei[g])<30 or yCoord[g]-(yCoord[l]+hei[l])<30) and ((xCoord[l]+wid[l])-(xCoord[g]) <30) and (xCoord[l]+wid[l])-(xCoord[g]) >0 ):
#                     if(w*h > 100 ):
#                         cv2.rectangle(result, (xCoord[l], yCoord[l]), ((xCoord[g]+wid[g]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
#             if( g>l  and (yCoord[l]-(yCoord[g]+hei[g])<30 or yCoord[g]-(yCoord[l]+hei[l])<30) and xCoord[g]-(xCoord[l]+wid[l]) <30 and xCoord[g]-(xCoord[l]+wid[l]) >0):
#                     if(w*h > 100 ):
#                         cv2.rectangle(result, (xCoord[l], yCoord[l]), ((xCoord[g]+wid[g]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
#                 if(hei[g]>hei[l]):
#                     cv2.rectangle(result, (xCoord[g], yCoord[g]), ((xCoord[l]+wid[l]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
#                 if(hei[g]<hei[l]):
#                     cv2.rectangle(result, (xCoord[g], (yCoord[l])), ((xCoord[l]+wid[l]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
    
#     for l in range(len(xCoord)): # to left and left top and left buttom and little inside
#         for g in range(len(xCoord)-1):
#               if( g>l and (yCoord[g]-(yCoord[l]+hei[l])<15 or yCoord[l]-(yCoord[g]+hei[g])<15) and ((xCoord[g]+wid[g])-(xCoord[l]) <15) and (xCoord[g]+wid[g])-(xCoord[l]) >0 ):
#                     cv2.rectangle(result, (xCoord[g], yCoord[g]), ((xCoord[l]+wid[l]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
# # #                     print("hello")
#                 if(hei[g]>hei[l]):
#                     cv2.rectangle(result, (xCoord[g], yCoord[g]), ((xCoord[l]+wid[l]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
#                 if(hei[g]<hei[l]):
#                     cv2.rectangle(result, (xCoord[g], (yCoord[l])), ((xCoord[l]+wid[l]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
#     for l in range(len(xCoord)): # to left and left top and left buttom and inside
#         for g in range(len(xCoord)-1):
#               if( g>l and ((yCoord[l]-(yCoord[g]+hei[g])<15 and yCoord[l]-(yCoord[g]+hei[g])>0) or (yCoord[l]-(yCoord[g])<15 and yCoord[l]-(yCoord[g])>0)) and ((xCoord[g])-(xCoord[l]) > 0) and (xCoord[g]+wid[g])-(xCoord[l]+wid[l]) <0 ):
#                     cv2.rectangle(result, (xCoord[g], yCoord[g]), ((xCoord[l]+wid[l]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
# # #                     print("hello")
#                 if(hei[g]>hei[l]):
#                     cv2.rectangle(result, (xCoord[g], yCoord[g]), ((xCoord[l]+wid[l]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
#                 if(hei[g]<hei[l]):
#                     cv2.rectangle(result, (xCoord[l], (yCoord[l])), ((xCoord[l]+wid[l]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
                    
#     for l in range(len(xCoord)): # to left and left top and left buttom and little inside
#         for g in range(len(xCoord)-1):
#               if( g>l and (yCoord[l]-(yCoord[g]+hei[g])<15 or yCoord[g]-(yCoord[l]+hei[l])<15) and ((xCoord[l]+wid[l])-(xCoord[g]) <15) and (xCoord[l]+wid[l])-(xCoord[g]) >0 ):
#                     cv2.rectangle(result, (xCoord[l], yCoord[l]), ((xCoord[g]+wid[g]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
# # #                     print("hello")
#                 if(hei[g]>hei[l]):
#                     cv2.rectangle(result, (xCoord[l], yCoord[l]), ((xCoord[g]+wid[g]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
#                 if(hei[g]<hei[l]):
#                     cv2.rectangle(result, (xCoord[l], (yCoord[g])), ((xCoord[g]+wid[g]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
                    
#     for l in range(len(xCoord)): # to left and left top and left buttom
#         for g in range(len(xCoord)-1):
#               if( g>l  and (yCoord[l]-(yCoord[g]+hei[g])<15 or yCoord[g]-(yCoord[l]+hei[l])<15) and xCoord[g]-(xCoord[l]+wid[l]) <15 and xCoord[g]-(xCoord[l]+wid[l]) >0):
#                     cv2.rectangle(result, (xCoord[l], yCoord[l]), ((xCoord[g]+wid[g]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
# # #                     print("hello")
#                 if(hei[l]>hei[g]):
#                     cv2.rectangle(result, (xCoord[l], yCoord[l]), ((xCoord[g]+wid[g]), (yCoord[l]+hei[l])), (0, 0, 0), 2)
#                 if(hei[g]<hei[l]):
#                     cv2.rectangle(result, (xCoord[l], (yCoord[g])), ((xCoord[g]+wid[g]), (yCoord[g]+hei[g])), (0, 0, 0), 2)
##########################################################################################        
        
    #     # save resulting image
    cv2.imwrite('Fire-Images/fire'+str(i)+'.jpg',result)
    ################################################################################################################################
    for k in range(len(xCoord)-1):
        dct[k] = {"X-cord":xCoord[k],"Y-cord":yCoord[k],"Height":hei[k],"Width":wid[k],"Area":area[k]}
        dat = dat + [dct[k]]
        dataa = pd.DataFrame(dat)
#         # storing into the excel file
    dataa.to_excel("outputData.xlsx") 

  ##########################################################################  
    imgee = PIL.Image.open('Fire-Images/fire'+str(i)+'.jpg')
    width = imgee.width
    height = imgee.height
    print(str(effectiveArea)+ " / " + str(width*height))     # FOR CALCULATNG TOTAL FIRED AREA AND TOTAL AREA OF IMAGE
    print(str(((effectiveArea)/(width*height))*100) + "% area is Fired")
  ###########################################################################  
    
    
    Imagee = Imagee + ['Fire-Images/fire'+str(i)+'.jpg']
  
    cv2.imshow("image", result)
    cv2.waitKey(0)

# clips = []
# for i in range(len(Imagee)):
#     clip =  ImageClip(Imagee[i]).set_duration(2)
#     clips.append(clip)

# video_clip = concatenate_videoclips(clips, method='compose')
# video_clip = video_clip.speedx(50)
# video_clip.write_videofile("Fire10.mp4", fps=30, remove_temp=True, codec="libx264", audio_codec="aac")
# Out:
# 47481 / 588800
# 8.064028532608695% area is Fired

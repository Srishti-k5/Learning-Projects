# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import tensorflow as tensorflow
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15028\2097447090.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
df = pd.read_csv('forestfires.csv')
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
df.hist(column='area')
# Out:
# array([[<Axes: title={'center': 'area'}>]], dtype=object)

# %%
df['size_category'] = np.where(df['area']>6, '1', '0')
df.tail(10)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 507  2  4   aug  fri  91.0  166.9  752.6   7.1  25.9  41   3.6   0.0   0.00
# 508  1  2   aug  fri  91.0  166.9  752.6   7.1  25.9  41   3.6   0.0   0.00
# 509  5  4   aug  fri  91.0  166.9  752.6   7.1  21.1  71   7.6   1.4   2.17
# 510  6  5   aug  fri  91.0  166.9  752.6   7.1  18.2  62   5.4   0.0   0.43
# 511  8  6   aug  sun  81.6   56.7  665.6   1.9  27.8  35   2.7   0.0   0.00
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
#     size_category
# 507             0
# 508             0
# 509             0
# 510             0
# 511             0
# 512             1
# 513             1
# 514             1
# 515             0
# 516             0

# %%
sns.countplot(x="size_category", data=df)
# Out:
# <Axes: xlabel='size_category', ylabel='count'>

# %%
df['size_category']=pd.to_numeric(df['size_category'])

# %%
print('Total Data:', df.shape[0])
print('Total Features:', df.shape[1])
# Out:
# Total Data: 517
# Total Features: 14

# %%
df.isnull().sum()
# Out:
# X                0
# Y                0
# month            0
# day              0
# FFMC             0
# DMC              0
# DC               0
# ISI              0
# temp             0
# RH               0
# wind             0
# rain             0
# area             0
# size_category    0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                count        mean         std   min    25%     50%     75%  \
# X              517.0    4.669246    2.313778   1.0    3.0    4.00    7.00
# Y              517.0    4.299807    1.229900   2.0    4.0    4.00    5.00
# FFMC           517.0   90.644681    5.520111  18.7   90.2   91.60   92.90
# DMC            517.0  110.872340   64.046482   1.1   68.6  108.30  142.40
# DC             517.0  547.940039  248.066192   7.9  437.7  664.20  713.90
# ISI            517.0    9.021663    4.559477   0.0    6.5    8.40   10.80
# temp           517.0   18.889168    5.806625   2.2   15.5   19.30   22.80
# RH             517.0   44.288201   16.317469  15.0   33.0   42.00   53.00
# wind           517.0    4.017602    1.791653   0.4    2.7    4.00    4.90
# rain           517.0    0.021663    0.295959   0.0    0.0    0.00    0.00
# area           517.0   12.847292   63.655818   0.0    0.0    0.52    6.57
# size_category  517.0    0.268859    0.443796   0.0    0.0    0.00    1.00
#
#                    max
# X                 9.00
# Y                 9.00
# FFMC             96.20
# DMC             291.30
# DC              860.60
# ISI              56.10
# temp             33.30
# RH              100.00
# wind              9.40
# rain              6.40
# area           1090.84
# size_category     1.00

# %%
fig, ax = plt.subplots(figsize=(16,10))  
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15028\2515665730.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
df['month'] = pd.Categorical(df['month'], categories=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
sns.countplot(x='month', data=df)
plt.title('Count plot of months')
# Out:
# Text(0.5, 1.0, 'Count plot of months')

# %%
# dictionary of months mapping to seasons
season_dict = {'dec': 'winter', 'jan': 'winter', 'feb': 'winter',
               'mar': 'spring', 'apr': 'spring', 'may': 'spring',
               'jun': 'summer', 'jul': 'summer', 'aug': 'summer', 'sep': 'summer',
               'oct': 'autumn', 'nov': 'autumn'}

# Check if the 'month' column exists in the DataFrame
if 'month' in df.columns:
    # create a new column 'season' by mapping 'month' column using the season_dict
    df['season'] = df['month'].map(season_dict)

    # visualize data
    sns.countplot(data=df, x='season')
    plt.title('Count plot of seasons')

    # display the plot
    plt.show()
else:
    print("The 'month' column does not exist in the DataFrame.")

# %%
# converting to is summer
df['season'] = (df['season'] == 'summer')

# renaming column
df = df.rename(columns = {'season' : 'is_summer'})

# visualizing data
sns.countplot(df['is_summer'])
plt.title('Count plot of summer vs other seasons')
# Out:
# Text(0.5, 1.0, 'Count plot of summer vs other seasons')

# %%
df['day'] = pd.Categorical(df['day'], categories=['fri', 'sat', 'sun','mon', 'tus', 'wed', 'thr'])
sns.countplot(x='day', data=df)
# sns.countplot(df['day'])
plt.title('Count plot of days')
# Out:
# Text(0.5, 1.0, 'Count plot of days')

# %%
# converting to is weekend
df['day'] = ((df['day'] == 'sun') | (df['day'] == 'sat'))

# renaming column
df = df.rename(columns = {'day' : 'is_weekend'})

# visualizing
sns.countplot(df['is_weekend'])
plt.title('Count plot of weekend vs weekday')
# Out:
# Text(0.5, 1.0, 'Count plot of weekend vs weekday')

# %%
# subplots
fig, ax = plt.subplots(11, figsize = (7,25))

# initial index
index = 0
unused_column = ['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area']

# visualizing
for column in unused_column:
    if column != 'is_summer':
        ax[index].hist(df[column])
        ax[index].title.set_text('histogram of ' + column)
        index += 1

# making plots visible
plt.tight_layout()

# %%
# natural logarithm scaling (+1 to prevent errors at 0)
df.loc[:, ['rain', 'area']] = df.loc[:, ['rain', 'area']].apply(lambda x: np.log(x + 1), axis = 1)

# visualizing
fig, ax = plt.subplots(2, figsize = (5, 8))

ax[0].hist(df['rain'])
ax[0].title.set_text('histogram of rain')

ax[1].hist(df['area'])
ax[1].title.set_text('histogram of area')

# %%
features = df.drop(['size_category'], axis = 1)
labels = df['size_category'].values.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(features,
                                                    labels,
                                                    test_size = 0.2,
                                                    random_state = 42)

X_train
# X_train = df.drop(['month'], axis = 1)
# Out:
#      X  Y month  is_weekend  FFMC    DMC     DC   ISI  temp  RH  wind  rain  \
# 329  4  3   sep        True  92.2  102.3  751.5   8.4  23.5  27   4.0   0.0
# 173  4  4   sep       False  90.9  126.5  686.5   7.0  17.7  39   2.2   0.0
# 272  2  5   aug       False  92.1  152.6  658.2  14.3  20.2  47   4.0   0.0
# 497  3  4   aug       False  96.1  181.1  671.2  14.3  32.3  27   2.2   0.0
# 182  5  4   feb        True  86.8   15.6   48.3   3.9  12.4  53   2.2   0.0
# ..  .. ..   ...         ...   ...    ...    ...   ...   ...  ..   ...   ...
# 71   4  5   sep       False  94.3   85.1  692.3  15.9  17.7  37   3.6   0.0
# 106  4  5   mar       False  91.4   30.7   74.3   7.5  18.2  29   3.1   0.0
# 270  2  2   aug       False  92.1  152.6  658.2  14.3  21.8  56   3.1   0.0
# 435  2  5   jul        True  90.8   84.7  376.6   5.6  23.8  51   1.8   0.0
# 102  2  4   aug       False  94.8  108.3  647.1  17.0  20.1  40   4.0   0.0
#
#          area  is_summer
# 329  1.465568       True
# 173  1.403643       True
# 272  1.408545       True
# 497  2.752386       True
# 182  1.998774      False
# ..        ...        ...
# 71   0.000000       True
# 106  0.000000      False
# 270  0.418710       True
# 435  0.000000       True
# 102  0.000000       True
#
# [413 rows x 14 columns]

# %%
# # fitting scaler
numeric_columns = ['X', 'Y','is_summer','is_weekend','FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area']

df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric)
sc_features = StandardScaler()

# transforming features
X_test[numeric_columns] = sc_features.fit_transform(X_test[numeric_columns])
X_train[numeric_columns] = sc_features.transform(X_train[numeric_columns])

X_train
# Out:
#             X         Y month  is_weekend      FFMC       DMC        DC  \
# 329 -0.293766 -0.927776   sep    1.404076  0.342959 -0.060220  0.867158
# 173 -0.293766 -0.161993   sep   -0.712212 -0.057456  0.370353  0.600021
# 272 -1.130796  0.603791   aug   -0.712212  0.312158  0.834731  0.483714
# 497 -0.712281 -0.161993   aug   -0.712212  1.544206  1.341810  0.537142
# 182  0.124750 -0.161993   feb    1.404076 -1.320305 -1.602809 -2.022846
# ..        ...       ...   ...         ...       ...       ...       ...
# 71  -0.293766  0.603791   sep   -0.712212  0.989785 -0.366247  0.623858
# 106 -0.293766  0.603791   mar   -0.712212  0.096550 -1.334146 -1.915992
# 270 -1.130796 -1.693559   aug   -0.712212  0.312158  0.834731  0.483714
# 435 -1.130796  0.603791   jul    1.404076 -0.088257 -0.373364 -0.673602
# 102 -1.130796 -0.161993   aug   -0.712212  1.143791  0.046534  0.438096
#
#           ISI      temp        RH      wind      rain      area  is_summer
# 329 -0.249015  0.784070 -1.071784 -0.054362 -0.137348  0.219260    0.53287
# 173 -0.465731 -0.203920 -0.279375 -1.042369 -0.137348  0.177491    0.53287
# 272  0.664288  0.221938  0.248898 -0.054362 -0.137348  0.180797    0.53287
# 497  0.664288  2.283090 -1.071784 -1.042369 -0.137348  1.087255    0.53287
# 182 -0.945602 -1.106740  0.645102 -1.042369 -0.137348  0.578923   -1.87663
# ..        ...       ...       ...       ...       ...       ...        ...
# 71   0.911963 -0.203920 -0.411443 -0.273919 -0.137348 -0.769306    0.53287
# 106 -0.388332 -0.118749 -0.939716 -0.548365 -0.137348 -0.769306   -1.87663
# 270  0.664288  0.494487  0.843205 -0.548365 -0.137348 -0.486874    0.53287
# 435 -0.682447  0.835173  0.513034 -1.261926 -0.137348 -0.769306    0.53287
# 102  1.082240  0.204903 -0.213341 -0.054362 -0.137348 -0.769306    0.53287
#
# [413 rows x 14 columns]

# %%
# features
# X_test = pd.DataFrame(X_test[numeric_columns], columns = features.columns)
# X_train = pd.DataFrame(X_train[numeric_columns], columns = features.columns)

# # labels
# y_test = pd.DataFrame(y_test, columns = ['size_category'])
# y_train = pd.DataFrame(y_train, columns = ['size_category'])
X_train = X_train[numeric_columns]
X_test = X_test[numeric_columns]

# %%
X_train.head()
# Out:
#             X         Y  is_summer  is_weekend      FFMC       DMC        DC  \
# 329 -0.293766 -0.927776    0.53287    1.404076  0.342959 -0.060220  0.867158
# 173 -0.293766 -0.161993    0.53287   -0.712212 -0.057456  0.370353  0.600021
# 272 -1.130796  0.603791    0.53287   -0.712212  0.312158  0.834731  0.483714
# 497 -0.712281 -0.161993    0.53287   -0.712212  1.544206  1.341810  0.537142
# 182  0.124750 -0.161993   -1.87663    1.404076 -1.320305 -1.602809 -2.022846
#
#           ISI      temp        RH      wind      rain      area
# 329 -0.249015  0.784070 -1.071784 -0.054362 -0.137348  0.219260
# 173 -0.465731 -0.203920 -0.279375 -1.042369 -0.137348  0.177491
# 272  0.664288  0.221938  0.248898 -0.054362 -0.137348  0.180797
# 497  0.664288  2.283090 -1.071784 -1.042369 -0.137348  1.087255
# 182 -0.945602 -1.106740  0.645102 -1.042369 -0.137348  0.578923

# %%
model = Sequential()

# %%
# input layer + 1st hidden layer
model.add(Dense(6, input_dim=13, activation='relu'))
# 2nd hidden layer
model.add(Dense(6, activation='relu'))
# output layer
model.add(Dense(6, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 84
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 6)                 42
#
#  dropout (Dropout)           (None, 6)                 0
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 175
# Trainable params: 175
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.compile(optimizer = 'adam', metrics=['accuracy'], loss = 'binary_crossentropy')

# %%
history = model.fit(X_train,
                    y_train,
                    validation_data = (X_test, y_test), 
                    batch_size = 10,
                    epochs = 100)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 6ms/step - loss: 3.9052 - accuracy: 0.7288 - val_loss: 4.0515 - val_accuracy: 0.7308
# Epoch 2/100
# 42/42 [==============================] - 0s 3ms/step - loss: 3.8995 - accuracy: 0.7337 - val_loss: 4.0415 - val_accuracy: 0.7308
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 3.7452 - accuracy: 0.7312 - val_loss: 4.0308 - val_accuracy: 0.7308
# Epoch 4/100
# 42/42 [==============================] - 0s 2ms/step - loss: 3.4430 - accuracy: 0.7312 - val_loss: 3.9159 - val_accuracy: 0.7308
# Epoch 5/100
# 42/42 [==============================] - 0s 3ms/step - loss: 3.3056 - accuracy: 0.7215 - val_loss: 3.6765 - val_accuracy: 0.7308
# Epoch 6/100
# 42/42 [==============================] - 0s 3ms/step - loss: 2.9823 - accuracy: 0.7191 - val_loss: 3.4388 - val_accuracy: 0.7212
# Epoch 7/100
# 42/42 [==============================] - 0s 3ms/step - loss: 2.3991 - accuracy: 0.6973 - val_loss: 2.1912 - val_accuracy: 0.7019
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.8748 - accuracy: 0.6683 - val_loss: 1.3768 - val_accuracy: 0.6923
# Epoch 9/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.4238 - accuracy: 0.6320 - val_loss: 0.9651 - val_accuracy: 0.6635
# Epoch 10/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.2186 - accuracy: 0.6901 - val_loss: 0.9606 - val_accuracy: 0.6731
# Epoch 11/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.3080 - accuracy: 0.6392 - val_loss: 0.9297 - val_accuracy: 0.6731
# Epoch 12/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1181 - accuracy: 0.6707 - val_loss: 0.6844 - val_accuracy: 0.6731
# Epoch 13/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.1373 - accuracy: 0.6804 - val_loss: 0.6536 - val_accuracy: 0.6635
# Epoch 14/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.2772 - accuracy: 0.6683 - val_loss: 0.6382 - val_accuracy: 0.6538
# Epoch 15/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.0570 - accuracy: 0.6877 - val_loss: 0.6212 - val_accuracy: 0.6538
# Epoch 16/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.1190 - accuracy: 0.7070 - val_loss: 0.6120 - val_accuracy: 0.6731
# Epoch 17/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.0478 - accuracy: 0.6804 - val_loss: 0.6007 - val_accuracy: 0.6635
# Epoch 18/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9412 - accuracy: 0.6925 - val_loss: 0.5889 - val_accuracy: 0.6827
# Epoch 19/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0
100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2227 - accuracy: 0.9153 - val_loss: 0.1739 - val_accuracy: 0.9423
# Epoch 83/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1989 - accuracy: 0.9249 - val_loss: 0.1701 - val_accuracy: 0.9423
# Epoch 84/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2802 - accuracy: 0.9056 - val_loss: 0.1680 - val_accuracy: 0.9423
# Epoch 85/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1795 - accuracy: 0.9419 - val_loss: 0.1651 - val_accuracy: 0.9423
# Epoch 86/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1627 - accuracy: 0.9201 - val_loss: 0.1628 - val_accuracy: 0.9423
# Epoch 87/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.9201 - val_loss: 0.1608 - val_accuracy: 0.9423
# Epoch 88/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.9274 - val_loss: 0.1570 - val_accuracy: 0.9423
# Epoch 89/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1783 - accuracy: 0.9322 - val_loss: 0.1530 - val_accuracy: 0.9231
# Epoch 90/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.9298 - val_loss: 0.1499 - val_accuracy: 0.9519
# Epoch 91/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2697 - accuracy: 0.9177 - val_loss: 0.1463 - val_accuracy: 0.9519
# Epoch 92/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1468 - accuracy: 0.9419 - val_loss: 0.1437 - val_accuracy: 0.9615
# Epoch 93/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2372 - accuracy: 0.9298 - val_loss: 0.1405 - val_accuracy: 0.9519
# Epoch 94/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1215 - accuracy: 0.9613 - val_loss: 0.1375 - val_accuracy: 0.9519
# Epoch 95/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9298 - val_loss: 0.1337 - val_accuracy: 0.9615
# Epoch 96/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1774 - accuracy: 0.9370 - val_loss: 0.1301 - val_accuracy: 0.9615
# Epoch 97/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1399 - accuracy: 0.9346 - val_loss: 0.1276 - val_accuracy: 0.9615
# Epoch 98/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1178 - accuracy: 0.9492 - val_loss: 0.1243 - val_accuracy: 0.9615
# Epoch 99/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 0.9516 - val_loss: 0.1226 - val_accuracy: 0.9615
# Epoch 100/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1152 - accuracy: 0.9467 - val_loss: 0.1208 - val_accuracy: 0.9615

# %%
_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, valid_acc = model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc, valid_acc))
# Out:
# Train: 0.976, Valid: 0.962

# %%
plt.figure(figsize=[8,5])
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves Epoch 100, Batch Size 10', fontsize=16)

plt.show()

# %%
features_coba = df.drop(['size_category','X','Y'], axis = 1)
labels_coba = df['size_category'].values.reshape(-1, 1)

# %%
features_coba
# Out:
#     month  is_weekend  FFMC    DMC     DC   ISI  temp  RH  wind      rain  \
# 0     mar       False  86.2   26.2   94.3   5.1   8.2  51   6.7  0.000000
# 1     oct       False  90.6   35.4  669.1   6.7  18.0  33   0.9  0.000000
# 2     oct        True  90.6   43.7  686.9   6.7  14.6  33   1.3  0.000000
# 3     mar       False  91.7   33.3   77.5   9.0   8.3  97   4.0  0.182322
# 4     mar        True  89.3   51.3  102.2   9.6  11.4  99   1.8  0.000000
# ..    ...         ...   ...    ...    ...   ...   ...  ..   ...       ...
# 512   aug        True  81.6   56.7  665.6   1.9  27.8  32   2.7  0.000000
# 513   aug        True  81.6   56.7  665.6   1.9  21.9  71   5.8  0.000000
# 514   aug        True  81.6   56.7  665.6   1.9  21.2  70   6.7  0.000000
# 515   aug        True  94.4  146.0  614.7  11.3  25.6  42   4.0  0.000000
# 516   nov       False  79.5    3.0  106.7   1.1  11.8  31   4.5  0.000000
#
#          area  is_summer
# 0    0.000000      False
# 1    0.000000      False
# 2    0.000000      False
# 3    0.000000      False
# 4    0.000000      False
# ..        ...        ...
# 512  2.006871       True
# 513  4.012592       True
# 514  2.498152       True
# 515  0.000000       True
# 516  0.000000      False
#
# [517 rows x 12 columns]

# %%
X_train_coba, X_test_coba, y_train_coba, y_test_coba = train_test_split(features_coba,
                                                                        labels_coba,
                                                                        test_size = 0.2,
                                                                        random_state = 42)

# %%
# fitting scaler

numeric_columns = ['is_summer','is_weekend','FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain', 'area']
sc_features = StandardScaler()

# transforming features
X_test_coba[numeric_columns] = sc_features.fit_transform(X_test_coba[numeric_columns])
X_train_coba[numeric_columns] = sc_features.transform(X_train_coba[numeric_columns])

# %%
# X_train = X_train[numeric_columns]
# X_test = X_test[numeric_columns]
X_test_coba = X_test_coba[numeric_columns]
X_train_coba = X_train_coba[numeric_columns]

# %%
X_train_coba.head()
# Out:
#      is_summer  is_weekend      FFMC       DMC        DC       ISI      temp  \
# 329    0.53287    1.404076  0.342959 -0.060220  0.867158 -0.249015  0.784070
# 173    0.53287   -0.712212 -0.057456  0.370353  0.600021 -0.465731 -0.203920
# 272    0.53287   -0.712212  0.312158  0.834731  0.483714  0.664288  0.221938
# 497    0.53287   -0.712212  1.544206  1.341810  0.537142  0.664288  2.283090
# 182   -1.87663    1.404076 -1.320305 -1.602809 -2.022846 -0.945602 -1.106740
#
#            RH      wind      rain      area
# 329 -1.071784 -0.054362 -0.137348  0.219260
# 173 -0.279375 -1.042369 -0.137348  0.177491
# 272  0.248898 -0.054362 -0.137348  0.180797
# 497 -1.071784 -1.042369 -0.137348  1.087255
# 182  0.645102 -1.042369 -0.137348  0.578923

# %%
model_coba = Sequential()

# %%
# input layer + 1st hidden layer
model_coba.add(Dense(6, input_dim=11, activation='relu'))
# 2nd hidden layer
model_coba.add(Dense(6, activation='relu'))
# output layer
model_coba.add(Dense(6, activation='sigmoid'))
model_coba.add(Dropout(0.2))
model_coba.add(Dense(1, activation = 'relu'))

# %%
model_coba.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 6)                 72
#
#  dense_5 (Dense)             (None, 6)                 42
#
#  dense_6 (Dense)             (None, 6)                 42
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_7 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 163
# Trainable params: 163
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_coba.compile(optimizer = 'adam', metrics=['accuracy'], loss = 'binary_crossentropy')

# %%
history_coba = model_coba.fit(X_train_coba,
                    y_train_coba,
                    validation_data = (X_test_coba, y_test_coba), 
                    batch_size = 10,
                    epochs = 100)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 6ms/step - loss: 1.4405 - accuracy: 0.6852 - val_loss: 0.5532 - val_accuracy: 0.7308
# Epoch 2/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9588 - accuracy: 0.6610 - val_loss: 0.5433 - val_accuracy: 0.7308
# Epoch 3/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1.5679 - accuracy: 0.6707 - val_loss: 0.5364 - val_accuracy: 0.7308
# Epoch 4/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.3116 - accuracy: 0.6707 - val_loss: 0.5286 - val_accuracy: 0.7308
# Epoch 5/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.0546 - accuracy: 0.6683 - val_loss: 0.5041 - val_accuracy: 0.7308
# Epoch 6/100
# 42/42 [==============================] - 0s 2ms/step - loss: 1
100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9903 - val_loss: 0.1793 - val_accuracy: 0.9712
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9879 - val_loss: 0.1838 - val_accuracy: 0.9712
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0383 - accuracy: 0.9831 - val_loss: 0.0468 - val_accuracy: 0.9712
# Epoch 75/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9903 - val_loss: 0.0550 - val_accuracy: 0.9808
# Epoch 76/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9903 - val_loss: 0.0691 - val_accuracy: 0.9808
# Epoch 77/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9855 - val_loss: 0.1324 - val_accuracy: 0.9808
# Epoch 78/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9903 - val_loss: 0.0743 - val_accuracy: 0.9808
# Epoch 79/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9952 - val_loss: 0.0635 - val_accuracy: 0.9808
# Epoch 80/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9808
# Epoch 81/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9903 - val_loss: 0.0800 - val_accuracy: 0.9808
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.9927 - val_loss: 0.0750 - val_accuracy: 0.9808
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9758 - val_loss: 0.0414 - val_accuracy: 0.9712
# Epoch 84/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9758 - val_loss: 0.0419 - val_accuracy: 0.9808
# Epoch 85/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1411 - accuracy: 0.9782 - val_loss: 0.0430 - val_accuracy: 0.9808
# Epoch 86/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1522 - accuracy: 0.9806 - val_loss: 0.0516 - val_accuracy: 0.9808
# Epoch 87/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1019 - accuracy: 0.9806 - val_loss: 0.0563 - val_accuracy: 0.9808
# Epoch 88/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9806 - val_loss: 0.1698 - val_accuracy: 0.9808
# Epoch 89/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9903 - val_loss: 0.1699 - val_accuracy: 0.9808
# Epoch 90/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9855 - val_loss: 0.1709 - val_accuracy: 0.9808
# Epoch 91/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9927 - val_loss: 0.1707 - val_accuracy: 0.9808
# Epoch 92/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9903 - val_loss: 0.1726 - val_accuracy: 0.9808
# Epoch 93/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9952 - val_loss: 0.1701 - val_accuracy: 0.9808
# Epoch 94/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9903 - val_loss: 0.1682 - val_accuracy: 0.9808
# Epoch 95/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9806 - val_loss: 0.1672 - val_accuracy: 0.9808
# Epoch 96/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9855 - val_loss: 0.1654 - val_accuracy: 0.9808
# Epoch 97/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9855 - val_loss: 0.1659 - val_accuracy: 0.9808
# Epoch 98/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9879 - val_loss: 0.1652 - val_accuracy: 0.9808
# Epoch 99/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9927 - val_loss: 0.1650 - val_accuracy: 0.9808
# Epoch 100/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9927 - val_loss: 0.1699 - val_accuracy: 0.9808

# %%
_, train_acc_coba = model_coba.evaluate(X_train_coba, y_train_coba, verbose=0)
_, valid_acc_coba = model_coba.evaluate(X_test_coba, y_test_coba, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc_coba, valid_acc_coba))
# Out:
# Train: 0.998, Valid: 0.981

# %%
plt.figure(figsize=[8,5])
plt.plot(history_coba.history['accuracy'], label='Train')
plt.plot(history_coba.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves Epoch 100 Batch Size 10', fontsize=16)

plt.show()

# %%
X_train
# Out:
#             X         Y  is_summer  is_weekend      FFMC       DMC        DC  \
# 329 -0.293766 -0.927776    0.53287    1.404076  0.342959 -0.060220  0.867158
# 173 -0.293766 -0.161993    0.53287   -0.712212 -0.057456  0.370353  0.600021
# 272 -1.130796  0.603791    0.53287   -0.712212  0.312158  0.834731  0.483714
# 497 -0.712281 -0.161993    0.53287   -0.712212  1.544206  1.341810  0.537142
# 182  0.124750 -0.161993   -1.87663    1.404076 -1.320305 -1.602809 -2.022846
# ..        ...       ...        ...         ...       ...       ...       ...
# 71  -0.293766  0.603791    0.53287   -0.712212  0.989785 -0.366247  0.623858
# 106 -0.293766  0.603791   -1.87663   -0.712212  0.096550 -1.334146 -1.915992
# 270 -1.130796 -1.693559    0.53287   -0.712212  0.312158  0.834731  0.483714
# 435 -1.130796  0.603791    0.53287    1.404076 -0.088257 -0.373364 -0.673602
# 102 -1.130796 -0.161993    0.53287   -0.712212  1.143791  0.046534  0.438096
#
#           ISI      temp        RH      wind      rain      area
# 329 -0.249015  0.784070 -1.071784 -0.054362 -0.137348  0.219260
# 173 -0.465731 -0.203920 -0.279375 -1.042369 -0.137348  0.177491
# 272  0.664288  0.221938  0.248898 -0.054362 -0.137348  0.180797
# 497  0.664288  2.283090 -1.071784 -1.042369 -0.137348  1.087255
# 182 -0.945602 -1.106740  0.645102 -1.042369 -0.137348  0.578923
# ..        ...       ...       ...       ...       ...       ...
# 71   0.911963 -0.203920 -0.411443 -0.273919 -0.137348 -0.769306
# 106 -0.388332 -0.118749 -0.939716 -0.548365 -0.137348 -0.769306
# 270  0.664288  0.494487  0.843205 -0.548365 -0.137348 -0.486874
# 435 -0.682447  0.835173  0.513034 -1.261926 -0.137348 -0.769306
# 102  1.082240  0.204903 -0.213341 -0.054362 -0.137348 -0.769306
#
# [413 rows x 13 columns]

# %%
# Fit a model and plot learning curve
def fit_model(X_train, y_train, X_test, y_test, n_batch):
  # Define Model
  model = Sequential()
  model.add(Dense(6, input_dim=13, activation='relu'))
  model.add(Dense(6, activation='relu'))
  model.add(Dense(6, activation='sigmoid'))
  model.add(Dropout(0.2))
  model.add(Dense(1, activation = 'relu'))

  # Compile Model
  model.compile(optimizer = 'adam',
                metrics=['accuracy'],
                loss = 'binary_crossentropy')
  
  # Fit Model
  history = model.fit(X_train,
                      y_train,
                      validation_data=(X_test, y_test),
                      epochs=100,
                      verbose=0,
                      batch_size=n_batch)

  # Plot Learning Curves
  plt.plot(history.history['accuracy'], label='train') 
  plt.plot(history.history['val_accuracy'], label='test') 
  plt.title('batch='+str(n_batch)) 
  plt.legend()

# %%
# Create learning curves for different batch sizes
batch_sizes = [4, 6, 10, 16, 32, 64, 128, 260]

plt.figure(figsize=(10,15))
for i in range(len(batch_sizes)):

  # Determine the Plot Number
  plot_no = 420 + (i+1)
  plt.subplot(plot_no)

  # Fit model and plot learning curves for a batch size
  fit_model(X_train, y_train, X_test, y_test, batch_sizes[i])

# Show learning curves
plt.show()

# %%
# fit a model and plot learning curve
def fit_model(trainX, trainy, validX, validy, n_epoch):
    
    # define model
    model = Sequential()
    model.add(Dense(6, input_dim=13, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    
    # compile model

    model.compile(optimizer ='adam',
                  metrics=['accuracy'],
                  loss = 'binary_crossentropy')
    
    # fit model
    history = model.fit(X_train,
                        y_train,
                        validation_data=(X_test, y_test),
                        epochs=n_epoch,
                        verbose=0,
                        batch_size=6)
    
    # plot learning curves
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='test')
    plt.title('epoch='+str(n_epoch))
    plt.legend()

# %%
# Create learning curves for different batch sizes
epochs = [20, 50, 100, 120, 150, 200, 300, 400]

plt.figure(figsize=(10,15))
for i in range(len(batch_sizes)):

  # Determine the Plot Number
  plot_no = 420 + (i+1)
  plt.subplot(plot_no)

  # Fit model and plot learning curves for a batch size
  fit_model(X_train, y_train, X_test, y_test, epochs[i])

# Show learning curves
plt.show()

# %%
def init_model():

    # define model
    model = Sequential()
    model.add(Dense(6, input_dim=13, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    
    model.compile(optimizer ='adam',
                  metrics=['accuracy'],
                  loss = 'binary_crossentropy')
    
    return model

# %%
# init model
model = init_model()

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   verbose=1,
                   patience=150)

# %%
mc = ModelCheckpoint('best_model.h5',
                     monitor='val_accuracy',
                     mode='max',
                     verbose=1,
                     save_best_only=True)

# %%
history = model.fit(X_train,
                    y_train,
                    validation_data=(X_test, y_test),
                    epochs=250,
                    verbose=0,
                    batch_size=6,
                    callbacks=[es, mc])
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.73077, saving model to best_model.h5
#
# Epoch 2: val_accuracy did not improve from 0.73077
#
# Epoch 3: val_accuracy did not improve from 0.73077
#
# Epoch 4: val_accuracy did not improve from 0.73077
#
# Epoch 5: val_accuracy did not improve from 0.73077
#
# Epoch 6: val_accuracy did not improve from 0.73077
#
# Epoch 7: val_accuracy did not improve from 0.73077
#
# Epoch 8: val_accuracy did not improve from 0.73077
#
# Epoch 9: val_accuracy did not improve from 0.73077
#
# Epoch 10: val_accuracy did not improve from 0.73077
#
# Epoch 11: val_accuracy did not improve from 0.73077
#
# Epoch 12: val_accuracy did not improve from 0.73077
#
# Epoch 13: val_accuracy improved from 0.73077 to 0.75962, saving model to best_model.h5
#
# Epoch 14: val_accuracy improved from 0.75962 to 0.80769, saving model to best_model.h5
#
# Epoch 15: val_accuracy improved from 0.80769 to 0.87500, saving model to best_model.h5
#
# Epoch 16: val_accuracy improved from 0.87500 to 0.97115, saving model to best_model.h5
#
# Epoch 17: val_accuracy did not improve from 0.97115
#
# Epoch 18: val_accuracy did not improve from 0.97115
#
# Epoch 19: val_accuracy did not improve from 0.97115
#
# Epoch 20: val_accuracy did not improve from 0.97115
#
# Epoch 21: val_accuracy did not improve from 0.97115
#
# Epoch 22: val_accuracy did not improve from 0.97115
#
# Epoch 23: val_accuracy did not improve from 0.97115
#
# Epoch 24: val_accuracy did not improve from 0.97115
#
# Epoch 25: val_accuracy did not improve from 0.97115
#
# Epoch 26: val_accuracy did not improve from 0.97115
#
# Epoch 27: val_accuracy improved from 0.97115 to 0.98077, saving model to best_model.h5
#
# Epoch 28: val_accuracy did not improve from 0.98077
#
# Epoch 29: val_accuracy did not improve from 0.98077
#
# Epoch 30: val_accuracy did not improve from 0.98077
#
# Epoch 31: val_accuracy did not improve from 0.98077
#
# Epoch 32: val_accuracy did not improve from 0.98077
#
# Epoch 33: val_accuracy did not improve from 0.98077
#
# Epoch 34: val_accuracy did not improve from 0.98077
#
# Epoch 35: val_accuracy did not improve from 0.98077
#
# Epoch 36: val_accuracy did not improve from 0.98077
#
# Epoch 37: val_accuracy did not improve from 0.98077
#
# Epoch 38: val_accuracy did not improve from 0.98077
#
# Epoch 39: val_accuracy did not improve from 0.98077
#
# Epoch 40: val_accuracy did not improve from 0.98077
#
# Epoch 41: val_accuracy did not improve from 0.98077
#
# Epoch 42: val_accuracy did not improve from 0.98077
#
# Epoch 43: val_accuracy did not improve from 0.98077
#
# Epoch 44: val_accuracy did not improve from 0.98077
#
# Epoch 45: val_accuracy did not improve from 0.98077
#
# Epoch 46: val_accuracy did not improve from 0.98077
#
# Epoch 47: val_accuracy did not improve from 0.98077
#
# Epoch 48: val_accuracy did not improve from 0.98077
#
# Epoch 49: val_accuracy did not improve from 0.98077
#
# Epoch 50: val_accuracy did not improve from 0.98077
#
# Epoch 51: val_accuracy did not improve from 0.98077
#
# Epoch 52: val_accuracy did not improve from 0.98077
#
# Epoch 53: val_accuracy did not improve from 0.98077
#
# Epoch 54: val_accuracy did not improve from 0.98077
#
# Epoch 55: val_accuracy did not improve from 0.98077
#
# Epoch 56: val_accuracy did not improve from 0.98077
#
# Epoch 57: val_accuracy did not improve from 0.98077
#
# Epoch 58: val_accuracy did not improve from 0.98077
#
# Epoch 59: val_accuracy did not improve from 0.98077
#
# Epoch 60: val_accuracy did not improve from 0.98077
#
# Epoch 61: val_accuracy did not improve from 0.98077
#
# Epoch 62: val_accuracy did not improve from 0.98077
#
# Epoch 63: val_accuracy did not improve from 0.98077
#
# Epoch 64: val_accuracy did not improve from 0.98077
#
# Epoch 65: val_accuracy did not improve from 0.98077
#
# Epoch 66: val_accuracy did not improve from 0.98077
#
# Epoch 67: val_accuracy did not improve from 0.98077
#
# Epoch 68: val_accuracy did not improve from 0.98077
#
# Epoch 69: val_accuracy did not improve from 0.98077
#
# Epoch 70: val_accuracy did not improve from 0.98077
#
# Epoch 71: val_accuracy did not improve from 0.98077
#
# Epoch 72: val_accuracy did not improve from 0.98077
#
# Epoch 73: val_accuracy did not improve from 0.98077
#
# Epoch 74: val_accuracy did not improve from 0.98077
#
# Epoch 75: val_accuracy did not improve from 0.98077
#
# Epoch 76: val_accuracy did not improve from 0.98077
#
# Epoch 77: val_accuracy did not improve from 0.98077
#
# Epoch 78: val_accuracy did not improve from 0.98077
#
# Epoch 79: val_accuracy did not improve from 0.98077
#
# Epoch 80: val_accuracy did not improve from 0.98077
#
# Epoch 81: val_accuracy did not improve from 0.98077
#
# Epoch 82: val_accuracy did not improve from 0.98077
#
# Epoch 83: val_accuracy did not improve from 0.98077
#
# Epoch 84: val_accuracy did not improve from 0.98077
#
# Epoch 85: val_accuracy did not improve from 0.98077
#
# Epoch 86: val_accuracy did not improve from 0.98077
#
# Epoch 87: val_accuracy did not improve from 0.98077
#
# Epoch 88: val_accuracy did not improve from 0.98077
#
# Epoch 89: val_accuracy did not improve from 0.98077
#
# Epoch 90: val_accuracy did not improve from 0.98077
#
# Epoch 91: val_accuracy did not improve from 0.98077
#
# Epoch 92: val_accuracy did not improve from 0.98077
#
# Epoch 93: val_accuracy did not improve from 0.98077
#
# Epoch 94: val_accuracy did not improve from 0.98077
#
# Epoch 95: val_accuracy did not improve from 0.98077
#
# Epoch 96: val_accuracy did not improve from 0.98077
#
# Epoch 97: val_accuracy did not improve from 0.98077
#
# Epoch 98: val_accuracy did not improve from 0.98077
#
# Epoch 99: val_accuracy did not improve from 0.98077
#
# Epoch 100: val_accuracy did not improve from 0.98077
#
# Epoch 101: val_accuracy did not improve from 0.98077
#
# Epoch 102: val_accuracy did not improve from 0.98077
#
# Epoch 103: val_accuracy did not improve from 0.98077
#
# Epoch 104: val_accuracy did not improve from 0.98077
#
# Epoch 105: val_accuracy did not improve from 0.98077
#
# Epoch 106: val_accuracy did not improve from 0.98077
#
# Epoch 107: val_accuracy did not improve from 0.98077
#
# Epoch 108: val_accuracy did not improve from 0.98077
#
# Epoch 109: val_accuracy did not improve from 0.98077
#
# Epoch 110: val_accuracy did not improve from 0.98077
#
# Epoch 111: val_accuracy did not improve from 0.98077
#
# Epoch 112: val_accuracy did not improve from 0.98077
#
# Epoch 113: val_accuracy did not improve from 0.98077
#
# Epoch 114: val_accuracy did not improve from 0.98077
#
# Epoch 115: val_accuracy did not improve from 0.98077
#
# Epoch 116: val_accuracy did not improve from 0.98077
#
# Epoch 117: val_accuracy did not improve from 0.98077
#
# Epoch 118: val_accuracy did not improve from 0.98077
#
# Epoch 119: val_accuracy did not improve from 0.98077
#
# Epoch 120: val_accuracy did not improve from 0.98077
#
# Epoch 121: val_accuracy did not improve from 0.98077
#
# Epoch 122: val_accuracy did not improve from 0.98077
#
# Epoch 123: val_accuracy did not improve from 0.98077
#
# Epoch 124: val_accuracy did not improve from 0.98077
#
# Epoch 125: val_accuracy did not improve from 0.98077
#
# Epoch 126: val_accuracy did not improve from 0.98077
#
# Epoch 127: val_accuracy did not improve from 0.98077
#
# Epoch 128: val_accuracy did not improve from 0.98077
#
# Epoch 129: val_accuracy did not improve from 0.98077
#
# Epoch 130: val_accuracy did not improve from 0.98077
#
# Epoch 131: val_accuracy did not improve from 0.98077
#
# Epoch 132: val_accuracy did not improve from 0.98077
#
# Epoch 133: val_accuracy did not improve from 0.98077
#
# Epoch 134: val_accuracy did not improve from 0.98077
#
# Epoch 135: val_accuracy did not improve from 0.98077
#
# Epoch 136: val_accuracy did not improve from 0.98077
#
# Epoch 137: val_accuracy did not improve from 0.98077
#
# Epoch 138: val_accuracy did not improve from 0.98077
#
# Epoch 139: val_accuracy did not improve from 0.98077
#
# Epoch 140: val_accuracy did not improve from 0.98077
#
# Epoch 141: val_accuracy did not improve from 0.98077
#
# Epoch 142: val_accuracy did not improve from 0.98077
#
# Epoch 143: val_accuracy did not improve from 0.98077
#
# Epoch 144: val_accuracy did not improve from 0.98077
#
# Epoch 145: val_accuracy did not improve from 0.98077
#
# Epoch 146: val_accuracy did not improve from 0.98077
#
# Epoch 147: val_accuracy did not improve from 0.98077
#
# Epoch 148: val_accuracy did not improve from 0.98077
#
# Epoch 149: val_accuracy did not improve from 0.98077
#
# Epoch 150: val_accuracy did not improve from 0.98077
#
# Epoch 151: val_accuracy did not improve from 0.98077
#
# Epoch 152: val_accuracy did not improve from 0.98077
#
# Epoch 153: val_accuracy did not improve from 0.98077
#
# Epoch 154: val_accuracy did not improve from 0.98077
#
# Epoch 155: val_accuracy did not improve from 0.98077
#
# Epoch 156: val_accuracy did not improve from 0.98077
#
# Epoch 157: val_accuracy did not improve from 0.98077
#
# Epoch 158: val_accuracy did not improve from 0.98077
#
# Epoch 159: val_accuracy did not improve from 0.98077
#
# Epoch 160: val_accuracy did not improve from 0.98077
#
# Epoch 161: val_accuracy did not improve from 0.98077
#
# Epoch 162: val_accuracy did not improve from 0.98077
#
# Epoch 163: val_accuracy did not improve from 0.98077
#
# Epoch 164: val_accuracy did not improve from 0.98077
#
# Epoch 165: val_accuracy did not improve from 0.98077
#
# Epoch 166: val_accuracy did not improve from 0.98077
#
# Epoch 167: val_accuracy did not improve from 0.98077
#
# Epoch 168: val_accuracy did not improve from 0.98077
#
# Epoch 169: val_accuracy did not improve from 0.98077
#
# Epoch 170: val_accuracy did not improve from 0.98077
#
# Epoch 171: val_accuracy did not improve from 0.98077
#
# Epoch 172: val_accuracy did not improve from 0.98077
#
# Epoch 173: val_accuracy did not improve from 0.98077
#
# Epoch 174: val_accuracy did not improve from 0.98077
#
# Epoch 175: val_accuracy did not improve from 0.98077
#
# Epoch 176: val_accuracy did not improve from 0.98077
#
# Epoch 177: val_accuracy did not improve from 0.98077
#
# Epoch 178: val_accuracy did not improve from 0.98077
#
# Epoch 179: val_accuracy did not improve from 0.98077
#
# Epoch 180: val_accuracy did not improve from 0.98077
#
# Epoch 181: val_accuracy did not improve from 0.98077
#
# Epoch 182: val_accuracy did not improve from 0.98077
#
# Epoch 183: val_accuracy did not improve from 0.98077
#
# Epoch 184: val_accuracy did not improve from 0.98077
#
# Epoch 185: val_accuracy did not improve from 0.98077
#
# Epoch 186: val_accuracy did not improve from 0.98077
#
# Epoch 187: val_accuracy did not improve from 0.98077
#
# Epoch 188: val_accuracy did not improve from 0.98077
#
# Epoch 189: val_accuracy did not improve from 0.98077
#
# Epoch 190: val_accuracy did not improve from 0.98077
#
# Epoch 191: val_accuracy did not improve from 0.98077
#
# Epoch 192: val_accuracy did not improve from 0.98077
# Epoch 192: early stopping

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='valid')
plt.legend()
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Curves', fontsize=16)
plt.show()

# %%
plt.figure(figsize=[8,5])
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)

plt.show()

# %%
from keras.models import load_model
model = load_model('best_model.h5')

# %%
_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, valid_acc = model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc, valid_acc))
# Out:
# Train: 0.971, Valid: 0.981

# %%
def fit_model_with_momentum(X_train, y_train, X_test, y_test, momentum):

    # define model
    model = Sequential()
    model.add(Dense(6, input_dim=13, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))

    # compile model
    opt = SGD(lr=0.1, momentum=momentum)
    model.compile(optimizer = opt,
                  metrics=['accuracy'],
                  loss = 'binary_crossentropy')

    # fit model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=394, verbose=0)
    
    # plot learning curves
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='test')
    plt.title('momentum='+str(momentum))
    plt.legend()

# %%
# create learning curves for different momentums
momentums = [0.0, 0.5, 0.8, 0.9, 0.99, 1.0] # use momentum values close to 1.0

plt.figure(figsize=(10, 15))
for i in range(len(momentums)):
    
    # determine the plot number
    plot_no = 320 + (i+1)
    plt.subplot(plot_no)
    
    # fit model and plot learning curves for a learning rate
    fit_model_with_momentum(X_train, y_train, X_test, y_test, momentums[i])

# show learning curves
plt.show()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
def init_model():

    # define model
    model = Sequential()
    model.add(Dense(6, input_dim=13, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation = 'relu'))
    opt = SGD(lr=0.1, momentum=0.9)
    model.compile(optimizer = opt,
                  metrics=['accuracy'],
                  loss = 'binary_crossentropy')
    
    return model

# %%
# init model
model = init_model()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
# simple early stopping
es = EarlyStopping(monitor='val_loss',
                   mode='min',
                   verbose=1,
                   patience=200)

# %%
mc = ModelCheckpoint('best_model_2.h5',
                     monitor='val_accuracy',
                     mode='max',
                     verbose=1,
                     save_best_only=True)

# %%
history = model.fit(X_train,
                    y_train,
                    validation_data=(X_test, y_test),
                    epochs=394,
                    verbose=0,
                    callbacks=[es, mc])
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.73077, saving model to best_model_2.h5
#
# Epoch 2: val_accuracy did not improve from 0.73077
#
# Epoch 3: val_accuracy did not improve from 0.73077
#
# Epoch 4: val_accuracy did not improve from 0.73077
#
# Epoch 5: val_accuracy did not improve from 0.73077
#
# Epoch 6: val_accuracy did not improve from 0.73077
#
# Epoch 7: val_accuracy did not improve from 0.73077
#
# Epoch 8: val_accuracy did not improve from 0.73077
#
# Epoch 9: val_accuracy did not improve from 0.73077
#
# Epoch 10: val_accuracy did not improve from 0.73077
#
# Epoch 11: val_accuracy did not improve from 0.73077
#
# Epoch 12: val_accuracy did not improve from 0.73077
#
# Epoch 13: val_accuracy did not improve from 0.73077
#
# Epoch 14: val_accuracy did not improve from 0.73077
#
# Epoch 15: val_accuracy did not improve from 0.73077
#
# Epoch 16: val_accuracy did not improve from 0.73077
#
# Epoch 17: val_accuracy did not improve from 0.73077
#
# Epoch 18: val_accuracy did not improve from 0.73077
#
# Epoch 19: val_accuracy did not improve from 0.73077
#
# Epoch 20: val_accuracy did not improve from 0.73077
#
# Epoch 21: val_accuracy did not improve from 0.73077
#
# Epoch 22: val_accuracy did not improve from 0.73077
#
# Epoch 23: val_accuracy did not improve from 0.73077
#
# Epoch 24: val_accuracy did not improve from 0.73077
#
# Epoch 25: val_accuracy did not improve from 0.73077
#
# Epoch 26: val_accuracy did not improve from 0.73077
#
# Epoch 27: val_accuracy did not improve from 0.73077
#
# Epoch 28: val_accuracy did not improve from 0.73077
#
# Epoch 29: val_accuracy did not improve from 0.73077
#
# Epoch 30: val_accuracy did not improve from 0.73077
#
# Epoch 31: val_accuracy did not improve from 0.73077
#
# Epoch 32: val_accuracy did not improve from 0.73077
#
# Epoch 33: val_accuracy did not improve from 0.73077
#
# Epoch 34: val_accuracy did not improve from 0.73077
#
# Epoch 35: val_accuracy did not improve from 0.73077
#
# Epoch 36: val_accuracy did not improve from 0.73077
#
# Epoch 37: val_accuracy did not improve from 0.73077
#
# Epoch 38: val_accuracy did not improve from 0.73077
#
# Epoch 39: val_accuracy did not improve from 0.73077
#
# Epoch 40: val_accuracy did not improve from 0.73077
#
# Epoch 41: val_accuracy did not improve from 0.73077
#
# Epoch 42: val_accuracy did not improve from 0.73077
#
# Epoch 43: val_accuracy did not improve from 0.73077
#
# Epoch 44: val_accuracy did not improve from 0.73077
#
# Epoch 45: val_accuracy did not improve from 0.73077
#
# Epoch 46: val_accuracy did not improve from 0.73077
#
# Epoch 47: val_accuracy did not improve from 0.73077
#
# Epoch 48: val_accuracy did not improve from 0.73077
#
# Epoch 49: val_accuracy did not improve from 0.73077
#
# Epoch 50: val_accuracy did not improve from 0.73077
#
# Epoch 51: val_accuracy did not improve from 0.73077
#
# Epoch 52: val_accuracy did not improve from 0.73077
#
# Epoch 53: val_accuracy did not improve from 0.73077
#
# Epoch 54: val_accuracy did not improve from 0.73077
#
# Epoch 55: val_accuracy did not improve from 0.73077
#
# Epoch 56: val_accuracy did not improve from 0.73077
#
# Epoch 57: val_accuracy did not improve from 0.73077
#
# Epoch 58: val_accuracy did not improve from 0.73077
#
# Epoch 59: val_accuracy did not improve from 0.73077
#
# Epoch 60: val_accuracy did not improve from 0.73077
#
# Epoch 61: val_accuracy did not improve from 0.73077
#
# Epoch 62: val_accuracy did not improve from 0.73077
#
# Epoch 63: val_accuracy did not improve from 0.73077
#
# Epoch 64: val_accuracy did not improve from 0.73077
#
# Epoch 65: val_accuracy did not improve from 0.73077
#
# Epoch 66: val_accuracy did not improve from 0.73077
#
# Epoch 67: val_accuracy did not improve from 0.73077
#
# Epoch 68: val_accuracy did not improve from 0.73077
#
# Epoch 69: val_accuracy did not improve from 0.73077
#
# Epoch 70: val_accuracy did not improve from 0.73077
#
# Epoch 71: val_accuracy did not improve from 0.73077
#
# Epoch 72: val_accuracy did not improve from 0.73077
#
# Epoch 73: val_accuracy did not improve from 0.73077
#
# Epoch 74: val_accuracy did not improve from 0.73077
#
# Epoch 75: val_accuracy did not improve from 0.73077
#
# Epoch 76: val_accuracy did not improve from 0.73077
#
# Epoch 77: val_accuracy did not improve from 0.73077
#
# Epoch 78: val_accuracy did not improve from 0.73077
#
# Epoch 79: val_accuracy did not improve from 0.73077
#
# Epoch 80: val_accuracy did not improve from 0.73077
#
# Epoch 81: val_accuracy did not improve from 0.73077
#
# Epoch 82: val_accuracy did not improve from 0.73077
#
# Epoch 83: val_accuracy did not improve from 0.73077
#
# Epoch 84: val_accuracy did not improve from 0.73077
#
# Epoch 85: val_accuracy did not improve from 0.73077
#
# Epoch 86: val_accuracy did not improve from 0.73077
#
# Epoch 87: val_accuracy did not improve from 0.73077
#
# Epoch 88: val_accuracy did not improve from 0.73077
#
# Epoch 89: val_accuracy did not improve from 0.73077
#
# Epoch 90: val_accuracy did not improve from 0.73077
#
# Epoch 91: val_accuracy did not improve from 0.73077
#
# Epoch 92: val_accuracy did not improve from 0.73077
#
# Epoch 93: val_accuracy did not improve from 0.73077
#
# Epoch 94: val_accuracy did not improve from 0.73077
#
# Epoch 95: val_accuracy did not improve from 0.73077
#
# Epoch 96: val_accuracy did not improve from 0.73077
#
# Epoch 97: val_accuracy did not improve from 0.73077
#
# Epoch 98: val_accuracy did not improve from 0.73077
#
# Epoch 99: val_accuracy did not improve from 0.73077
#
# Epoch 100: val_accuracy did not improve from 0.73077
#
# Epoch 101: val_accuracy did not improve from 0.73077
#
# Epoch 102: val_accuracy did not improve from 0.73077
#
# Epoch 103: val_accuracy did not improve from 0.73077
#
# Epoch 104: val_accuracy did not improve from 0.73077
#
# Epoch 105: val_accuracy did not improve from 0.73077
#
# Epoch 106: val_accuracy did not improve from 0.73077
#
# Epoch 107: val_accuracy did not improve from 0.73077
#
# Epoch 108: val_accuracy did not improve from 0.73077
#
# Epoch 109: val_accuracy did not improve from 0.73077
#
# Epoch 110: val_accuracy did not improve from 0.73077
#
# Epoch 111: val_accuracy did not improve from 0.73077
#
# Epoch 112: val_accuracy did not improve from 0.73077
#
# Epoch 113: val_accuracy did not improve from 0.73077
#
# Epoch 114: val_accuracy did not improve from 0.73077
#
# Epoch 115: val_accuracy did not improve from 0.73077
#
# Epoch 116: val_accuracy did not improve from 0.73077
#
# Epoch 117: val_accuracy did not improve from 0.73077
#
# Epoch 118: val_accuracy did not improve from 0.73077
#
# Epoch 119: val_accuracy did not improve from 0.73077
#
# Epoch 120: val_accuracy did not improve from 0.73077
#
# Epoch 121: val_accuracy did not improve from 0.73077
#
# Epoch 122: val_accuracy did not improve from 0.73077
#
# Epoch 123: val_accuracy did not improve from 0.73077
#
# Epoch 124: val_accuracy did not improve from 0.73077
#
# Epoch 125: val_accuracy did not improve from 0.73077
#
# Epoch 126: val_accuracy did not improve from 0.73077
#
# Epoch 127: val_accuracy did not improve from 0.73077
#
# Epoch 128: val_accuracy did not improve from 0.73077
#
# Epoch 129: val_accuracy did not improve from 0.73077
#
# Epoch 130: val_accuracy did not improve from 0.73077
#
# Epoch 131: val_accuracy did not improve from 0.73077
#
# Epoch 132: val_accuracy did not improve from 0.73077
#
# Epoch 133: val_accuracy did not improve from 0.73077
#
# Epoch 134: val_accuracy did not improve from 0.73077
#
# Epoch 135: val_accuracy did not improve from 0.73077
#
# Epoch 136: val_accuracy did not improve from 0.73077
#
# Epoch 137: val_accuracy did not improve from 0.73077
#
# Epoch 138: val_accuracy did not improve from 0.73077
#
# Epoch 139: val_accuracy did not improve from 0.73077
#
# Epoch 140: val_accuracy did not improve from 0.73077
#
# Epoch 141: val_accuracy did not improve from 0.73077
#
# Epoch 142: val_accuracy did not improve from 0.73077
#
# Epoch 143: val_accuracy did not improve from 0.73077
#
# Epoch 144: val_accuracy did not improve from 0.73077
#
# Epoch 145: val_accuracy did not improve from 0.73077
#
# Epoch 146: val_accuracy did not improve from 0.73077
#
# Epoch 147: val_accuracy did not improve from 0.73077
#
# Epoch 148: val_accuracy did not improve from 0.73077
#
# Epoch 149: val_accuracy did not improve from 0.73077
#
# Epoch 150: val_accuracy did not improve from 0.73077
#
# Epoch 151: val_accuracy did not improve from 0.73077
#
# Epoch 152: val_accuracy did not improve from 0.73077
#
# Epoch 153: val_accuracy did not improve from 0.73077
#
# Epoch 154: val_accuracy did not improve from 0.73077
#
# Epoch 155: val_accuracy did not improve from 0.73077
#
# Epoch 156: val_accuracy did not improve from 0.73077
#
# Epoch 157: val_accuracy did not improve from 0.73077
#
# Epoch 158: val_accuracy did not improve from 0.73077
#
# Epoch 159: val_accuracy did not improve from 0.73077
#
# Epoch 160: val_accuracy did not improve from 0.73077
#
# Epoch 161: val_accuracy did not improve from 0.73077
#
# Epoch 162: val_accuracy did not improve from 0.73077
#
# Epoch 163: val_accuracy did not improve from 0.73077
#
# Epoch 164: val_accuracy did not improve from 0.73077
#
# Epoch 165: val_accuracy did not improve from 0.73077
#
# Epoch 166: val_accuracy did not improve from 0.73077
#
# Epoch 167: val_accuracy did not improve from 0.73077
#
# Epoch 168: val_accuracy did not improve from 0.73077
#
# Epoch 169: val_accuracy did not improve from 0.73077
#
# Epoch 170: val_accuracy did not improve from 0.73077
#
# Epoch 171: val_accuracy did not improve from 0.73077
#
# Epoch 172: val_accuracy did not improve from 0.73077
#
# Epoch 173: val_accuracy did not improve from 0.73077
#
# Epoch 174: val_accuracy did not improve from 0.73077
#
# Epoch 175: val_accuracy did not improve from 0.73077
#
# Epoch 176: val_accuracy did not improve from 0.73077
#
# Epoch 177: val_accuracy did not improve from 0.73077
#
# Epoch 178: val_accuracy did not improve from 0.73077
#
# Epoch 179: val_accuracy did not improve from 0.73077
#
# Epoch 180: val_accuracy did not improve from 0.73077
#
# Epoch 181: val_accuracy did not improve from 0.73077
#
# Epoch 182: val_accuracy did not improve from 0.73077
#
# Epoch 183: val_accuracy did not improve from 0.73077
#
# Epoch 184: val_accuracy did not improve from 0.73077
#
# Epoch 185: val_accuracy did not improve from 0.73077
#
# Epoch 186: val_accuracy did not improve from 0.73077
#
# Epoch 187: val_accuracy did not improve from 0.73077
#
# Epoch 188: val_accuracy did not improve from 0.73077
#
# Epoch 189: val_accuracy did not improve from 0.73077
#
# Epoch 190: val_accuracy did not improve from 0.73077
#
# Epoch 191: val_accuracy did not improve from 0.73077
#
# Epoch 192: val_accuracy did not improve from 0.73077
#
# Epoch 193: val_accuracy did not improve from 0.73077
#
# Epoch 194: val_accuracy did not improve from 0.73077
#
# Epoch 195: val_accuracy did not improve from 0.73077
#
# Epoch 196: val_accuracy did not improve from 0.73077
#
# Epoch 197: val_accuracy did not improve from 0.73077
#
# Epoch 198: val_accuracy did not improve from 0.73077
#
# Epoch 199: val_accuracy did not improve from 0.73077
#
# Epoch 200: val_accuracy did not improve from 0.73077
#
# Epoch 201: val_accuracy did not improve from 0.73077
# Epoch 201: early stopping

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='valid')
plt.legend()
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Curves', fontsize=16)
plt.show()

# %%
plt.figure(figsize=[8,5])
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.legend()
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy Curves', fontsize=16)

plt.show()

# %%
from keras.models import load_model
model = load_model('best_model_2.h5')

# %%
_, train_acc = model.evaluate(X_train, y_train, verbose=0)
_, valid_acc = model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Valid: %.3f' % (train_acc, valid_acc))
# Out:
# Train: 0.734, Valid: 0.731
